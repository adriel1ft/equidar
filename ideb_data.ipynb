# %%
import pandas as pd
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
read_excel_file = pd.read_csv('data/PB_INFRAESTRUTURA_FUND_SCORE_2023.csv', engine='openpyxl')

# %%
ideb = pd.read_excel(
    "divulgacao_anos_iniciais_escolas_2023.xlsx",
    header=8
)

# %%
cols_nec_2023 = ['SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO', 'ID_ESCOLA', 'NO_ESCOLA', 'REDE', 'VL_APROVACAO_2023_SI_4', 'VL_INDICADOR_REND_2023', 'VL_NOTA_MATEMATICA_2023', 'VL_NOTA_PORTUGUES_2023', 'VL_NOTA_MEDIA_2023', 'VL_OBSERVADO_2023', 'VL_PROJECAO_2021']

# %%
if "SG_UF" not in ideb.columns:
	# make sure we treat header values as strings and strip whitespace
	ideb.columns = ideb.iloc[0].astype(str).str.strip()
	ideb = ideb[1:].reset_index(drop=True)

# filter for Paraíba (PB)
ideb_pb = ideb[(ideb["SG_UF"] == "PB") & (ideb["REDE"].isin(["Municipal", "Estadual", "Federal"]))].copy()

# %%
ideb_pb.head()
# Out:
# 0     SG_UF CO_MUNICIPIO NO_MUNICIPIO ID_ESCOLA  \
# 18619    PB      2500106  Água Branca  25033158
# 18620    PB      2500106  Água Branca  25033557
# 18621    PB      2500106  Água Branca  25033670
# 18622    PB      2500205       Aguiar  25023489
# 18623    PB      2500205       Aguiar  25023535
#
# 0                             NO_ESCOLA       REDE VL_APROVACAO_2005_SI_4  \
# 18619                    EMEIF MAE IAIA  Municipal                      -
# 18620     EMEIF DELFINO JOSE DOS SANTOS  Municipal                      -
# 18621    EMEF ANTONIO VIRGOLINO BATISTA  Municipal                   86.1
# 18622     ECI EEM AGENOR MENDES PEDROSA   Estadual                      -
# 18623  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal                      -
#
# 0     VL_APROVACAO_2005_SI VL_APROVACAO_2005_1 VL_APROVACAO_2005_2  ...  \
# 18619                    -                   -                   -  ...
# 18620                    -                   -                   -  ...
# ...

# %%
cols_exist = [c for c in cols_nec_2023 if c in ideb_pb.columns]
ideb_sel = ideb_pb[cols_exist].copy()
ideb_sel.head()
# Out:
# 0     SG_UF CO_MUNICIPIO NO_MUNICIPIO ID_ESCOLA  \
# 18619    PB      2500106  Água Branca  25033158
# 18620    PB      2500106  Água Branca  25033557
# 18621    PB      2500106  Água Branca  25033670
# 18622    PB      2500205       Aguiar  25023489
# 18623    PB      2500205       Aguiar  25023535
#
# 0                             NO_ESCOLA       REDE VL_APROVACAO_2023_SI_4  \
# 18619                    EMEIF MAE IAIA  Municipal                    100
# 18620     EMEIF DELFINO JOSE DOS SANTOS  Municipal                    100
# 18621    EMEF ANTONIO VIRGOLINO BATISTA  Municipal                      -
# 18622     ECI EEM AGENOR MENDES PEDROSA   Estadual                      -
# 18623  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal                      -
#
# 0     VL_INDICADOR_REND_2023 VL_NOTA_MATEMATICA_2023 VL_NOTA_PORTUGUES_2023  \
# 18619                      1                  253.97                 231.18
# ...

# %%
# sem selação das colunas, só salvar o PB
# ideb_pb.to_csv("pb_sheets/ideb_anos_iniciais_pb_2023.csv", index=False)

# %%
ideb_sel.to_csv("pb_sheets/ideb_anos_iniciais_pb_2023.csv", index=False)

# %% [markdown]
# ideb final

# %%
ideb_final = pd.read_excel(
    "divulgacao_anos_finais_escolas_2023.xlsx",
    header=9
)

# %%
if "SG_UF" not in ideb.columns:
	# make sure we treat header values as strings and strip whitespace
	ideb_final.columns = ideb_final.iloc[0].astype(str).str.strip()
	ideb_final = ideb_final[1:].reset_index(drop=True)

# filter for Paraíba (PB)
ideb_final_pb = ideb_final[(ideb_final["SG_UF"] == "PB") & (ideb_final["REDE"].isin(["Municipal", "Estadual", "Federal"]))].copy()

# %%
ideb_final_pb.head()
# Out:
#       SG_UF  CO_MUNICIPIO NO_MUNICIPIO   ID_ESCOLA  \
# 14151    PB     2500106.0  Água Branca  25033204.0
# 14152    PB     2500106.0  Água Branca  25033212.0
# 14153    PB     2500106.0  Água Branca  25033263.0
# 14154    PB     2500106.0  Água Branca  25033557.0
# 14155    PB     2500106.0  Água Branca  25033670.0
#
#                             NO_ESCOLA       REDE VL_APROVACAO_2005_SI_4  \
# 14151          ECI EEM JOSE NOMINANDO   Estadual                   68.3
# 14152    EEEF JOAO PEREIRA DOS SANTOS   Estadual                      -
# 14153   EEEF PEDRO HERCULANO DA SILVA   Estadual                      -
# 14154   EMEIF DELFINO JOSE DOS SANTOS  Municipal                      -
# 14155  EMEF ANTONIO VIRGOLINO BATISTA  Municipal                      -
#
#       VL_APROVACAO_2005_1 VL_APROVACAO_2005_2 VL_APROVACAO_2005_3  ...  \
# 14151                  50                68.2                  78  ...
# 14152                   -                   -                   -  ...
# ...

# %%
cols_exist = [c for c in cols_nec_2023 if c in ideb_pb.columns]
ideb_sel = ideb_pb[cols_exist].copy()
ideb_sel.head()
# Out:
# 0     SG_UF CO_MUNICIPIO NO_MUNICIPIO ID_ESCOLA  \
# 18619    PB      2500106  Água Branca  25033158
# 18620    PB      2500106  Água Branca  25033557
# 18621    PB      2500106  Água Branca  25033670
# 18622    PB      2500205       Aguiar  25023489
# 18623    PB      2500205       Aguiar  25023535
#
# 0                             NO_ESCOLA       REDE VL_APROVACAO_2023_SI_4  \
# 18619                    EMEIF MAE IAIA  Municipal                    100
# 18620     EMEIF DELFINO JOSE DOS SANTOS  Municipal                    100
# 18621    EMEF ANTONIO VIRGOLINO BATISTA  Municipal                      -
# 18622     ECI EEM AGENOR MENDES PEDROSA   Estadual                      -
# 18623  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal                      -
#
# 0     VL_INDICADOR_REND_2023 VL_NOTA_MATEMATICA_2023 VL_NOTA_PORTUGUES_2023  \
# 18619                      1                  253.97                 231.18
# ...

# %%
ideb_sel.to_csv("pb_sheets/ideb_anos_finais_pb_2023.csv", index=False)

# %% [markdown]
# ideb ensino medio

# %%
ideb_em = pd.read_excel(
    "divulgacao_ensino_medio_escolas_2023.xlsx",
    header=9
)

# %%
ideb_em.head()
# Out:
#   SG_UF  CO_MUNICIPIO           NO_MUNICIPIO   ID_ESCOLA  \
# 0    RO     1100015.0  Alta Floresta D'Oeste  11024682.0
# 1    RO     1100015.0  Alta Floresta D'Oeste  11024968.0
# 2    RO     1100015.0  Alta Floresta D'Oeste  11025638.0
# 3    RO     1100023.0              Ariquemes  11006773.0
# 4    RO     1100023.0              Ariquemes  11006889.0
#
#                                          NO_ESCOLA      REDE  \
# 0                     EEEFM EURIDICE LOPES PEDROSO  Estadual
# 1          EEEMTI JUSCELINO KUBITSCHEK DE OLIVEIRA  Estadual
# 2  COLEGIO TIRADENTES DA POLICIA MILITAR - CTPM XI  Estadual
# 3                              EEEFM CORA CORALINA  Estadual
# 4                            EEEFM ANISIO TEIXEIRA  Estadual
#
#   VL_APROVACAO_2017_SI_4 VL_APROVACAO_2017_1 VL_APROVACAO_2017_2  \
# 0                      -                   -                   -
# 1                   96.1                96.2                95.1
# ...

# %%
ideb_em_pb = ideb_em[(ideb_em["SG_UF"] == "PB") & (ideb_em["REDE"].isin(["Municipal", "Estadual", "Federal"]))].copy()

# %%
ideb_em_pb.head()
# Out:
#      SG_UF  CO_MUNICIPIO   NO_MUNICIPIO   ID_ESCOLA  \
# 4654    PB     2500106.0    Água Branca  25033204.0
# 4655    PB     2500205.0         Aguiar  25023489.0
# 4656    PB     2500304.0  Alagoa Grande  25062638.0
# 4657    PB     2500304.0  Alagoa Grande  25062816.0
# 4658    PB     2500403.0    Alagoa Nova  25063340.0
#
#                                        NO_ESCOLA      REDE  \
# 4654                      ECI EEM JOSE NOMINANDO  Estadual
# 4655               ECI EEM AGENOR MENDES PEDROSA  Estadual
# 4656                 EEEFM PADRE HILDON BANDEIRA  Estadual
# 4657  ECIT OSWALDO TRIGUEIRO DE ALBUQUERQUE MELO  Estadual
# 4658      ECIT MONSENHOR JOSE BORGES DE CARVALHO  Estadual
#
#      VL_APROVACAO_2017_SI_4 VL_APROVACAO_2017_1 VL_APROVACAO_2017_2  \
# 4654                   85.5                71.6                89.8
# 4655                   87.2                78.1                  87
# 4656                   64.8                50.4                69.6
# ...

# %%
cols_exist = [c for c in cols_nec_2023 if c in ideb_em_pb.columns]
ideb_em_sel = ideb_em_pb[cols_exist].copy()
ideb_em_sel.head()
# Out:
#      SG_UF  CO_MUNICIPIO   NO_MUNICIPIO   ID_ESCOLA  \
# 4654    PB     2500106.0    Água Branca  25033204.0
# 4655    PB     2500205.0         Aguiar  25023489.0
# 4656    PB     2500304.0  Alagoa Grande  25062638.0
# 4657    PB     2500304.0  Alagoa Grande  25062816.0
# 4658    PB     2500403.0    Alagoa Nova  25063340.0
#
#                                        NO_ESCOLA      REDE  \
# 4654                      ECI EEM JOSE NOMINANDO  Estadual
# 4655               ECI EEM AGENOR MENDES PEDROSA  Estadual
# 4656                 EEEFM PADRE HILDON BANDEIRA  Estadual
# 4657  ECIT OSWALDO TRIGUEIRO DE ALBUQUERQUE MELO  Estadual
# 4658      ECIT MONSENHOR JOSE BORGES DE CARVALHO  Estadual
#
#      VL_APROVACAO_2023_SI_4 VL_INDICADOR_REND_2023 VL_NOTA_MATEMATICA_2023  \
# 4654                   80.8               0.826845                  282.49
# 4655                   96.6               0.968462                  280.78
# ...

# %%
# sem seleção das colunas, só salvar o PB
# ideb_em_pb.to_csv("pb_sheets/ideb_ensino_medio_pb_2023.csv", index=False)

# %%
ideb_em_sel.to_csv("pb_sheets/ideb_ensino_medio_pb_2023_sel.csv", index=False)

# %% [markdown]
# Ideb dados 2017

# %%
cols_nec_2017 = ['SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO', 'ID_ESCOLA', 'NO_ESCOLA', 'REDE', 'VL_APROVACAO_2017_SI_4', 'VL_INDICADOR_REND_2017', 'VL_NOTA_MATEMATICA_2017', 'VL_NOTA_PORTUGUES_2017', 'VL_NOTA_MEDIA_2017', 'VL_OBSERVADO_2017' 'VL_PROJECAO_2017']

# %%
cols_exist = [c for c in cols_nec_2017 if c in ideb_em_pb.columns]
ideb_em_sel = ideb_em_pb[cols_exist].copy()
ideb_em_sel.head()
# Out:
#      SG_UF  CO_MUNICIPIO   NO_MUNICIPIO   ID_ESCOLA  \
# 4654    PB     2500106.0    Água Branca  25033204.0
# 4655    PB     2500205.0         Aguiar  25023489.0
# 4656    PB     2500304.0  Alagoa Grande  25062638.0
# 4657    PB     2500304.0  Alagoa Grande  25062816.0
# 4658    PB     2500403.0    Alagoa Nova  25063340.0
#
#                                        NO_ESCOLA      REDE  \
# 4654                      ECI EEM JOSE NOMINANDO  Estadual
# 4655               ECI EEM AGENOR MENDES PEDROSA  Estadual
# 4656                 EEEFM PADRE HILDON BANDEIRA  Estadual
# 4657  ECIT OSWALDO TRIGUEIRO DE ALBUQUERQUE MELO  Estadual
# 4658      ECIT MONSENHOR JOSE BORGES DE CARVALHO  Estadual
#
#      VL_APROVACAO_2017_SI_4 VL_INDICADOR_REND_2017 VL_NOTA_MATEMATICA_2017  \
# 4654                   85.5               0.839911                  273.19
# 4655                   87.2               0.874678                     237
# ...

# %%
ideb_em_sel.to_csv("pb_sheets/ideb_ensino_medio_pb_2017.csv", index=False)

# %%
cols_exist = [c for c in cols_nec_2017 if c in ideb_pb.columns]
ideb_sel = ideb_pb[cols_exist].copy()
ideb_sel.head()
# Out:
# 0     SG_UF CO_MUNICIPIO NO_MUNICIPIO ID_ESCOLA  \
# 18619    PB      2500106  Água Branca  25033158
# 18620    PB      2500106  Água Branca  25033557
# 18621    PB      2500106  Água Branca  25033670
# 18622    PB      2500205       Aguiar  25023489
# 18623    PB      2500205       Aguiar  25023535
#
# 0                             NO_ESCOLA       REDE VL_APROVACAO_2017_SI_4  \
# 18619                    EMEIF MAE IAIA  Municipal                   95.2
# 18620     EMEIF DELFINO JOSE DOS SANTOS  Municipal                   95.7
# 18621    EMEF ANTONIO VIRGOLINO BATISTA  Municipal                      -
# 18622     ECI EEM AGENOR MENDES PEDROSA   Estadual                    100
# 18623  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal                   73.1
#
# 0     VL_INDICADOR_REND_2017 VL_NOTA_MATEMATICA_2017 VL_NOTA_PORTUGUES_2017  \
# 18619               0.955293                  236.57                 214.85
# ...

# %%
ideb_sel.to_csv("pb_sheets/ideb_anos_iniciais_pb_2017.csv", index=False)

# %%
cols_exist = [c for c in cols_nec_2017 if c in ideb_final_pb.columns]
ideb_final_sel = ideb_final_pb[cols_exist].copy()
ideb_final_sel.head()
# Out:
#       SG_UF  CO_MUNICIPIO NO_MUNICIPIO   ID_ESCOLA  \
# 14151    PB     2500106.0  Água Branca  25033204.0
# 14152    PB     2500106.0  Água Branca  25033212.0
# 14153    PB     2500106.0  Água Branca  25033263.0
# 14154    PB     2500106.0  Água Branca  25033557.0
# 14155    PB     2500106.0  Água Branca  25033670.0
#
#                             NO_ESCOLA       REDE VL_APROVACAO_2017_SI_4  \
# 14151          ECI EEM JOSE NOMINANDO   Estadual                   80.9
# 14152    EEEF JOAO PEREIRA DOS SANTOS   Estadual                      -
# 14153   EEEF PEDRO HERCULANO DA SILVA   Estadual                      -
# 14154   EMEIF DELFINO JOSE DOS SANTOS  Municipal                   96.6
# 14155  EMEF ANTONIO VIRGOLINO BATISTA  Municipal                     89
#
#       VL_INDICADOR_REND_2017 VL_NOTA_MATEMATICA_2017 VL_NOTA_PORTUGUES_2017  \
# 14151                0.79805                  249.23                 249.06
# ...

# %%
ideb_final_sel.to_csv("pb_sheets/ideb_anos_finais_pb_2017.csv", index=False)

# %% [markdown]
# Ideb 2019

# %%
cols_nec_2019 = ['SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO', 'ID_ESCOLA', 'NO_ESCOLA', 'REDE', 'VL_APROVACAO_2019_SI_4', 'VL_INDICADOR_REND_2019', 'VL_NOTA_MATEMATICA_2019', 'VL_NOTA_PORTUGUES_2019', 'VL_NOTA_MEDIA_2019', 'VL_OBSERVADO_2019','VL_PROJECAO_2019']

# %%
cols_exist = [c for c in cols_nec_2019 if c in ideb_em_pb.columns]
ideb_em_sel = ideb_em_pb[cols_exist].copy()
ideb_em_sel.head()
# Out:
#      SG_UF  CO_MUNICIPIO   NO_MUNICIPIO   ID_ESCOLA  \
# 4654    PB     2500106.0    Água Branca  25033204.0
# 4655    PB     2500205.0         Aguiar  25023489.0
# 4656    PB     2500304.0  Alagoa Grande  25062638.0
# 4657    PB     2500304.0  Alagoa Grande  25062816.0
# 4658    PB     2500403.0    Alagoa Nova  25063340.0
#
#                                        NO_ESCOLA      REDE  \
# 4654                      ECI EEM JOSE NOMINANDO  Estadual
# 4655               ECI EEM AGENOR MENDES PEDROSA  Estadual
# 4656                 EEEFM PADRE HILDON BANDEIRA  Estadual
# 4657  ECIT OSWALDO TRIGUEIRO DE ALBUQUERQUE MELO  Estadual
# 4658      ECIT MONSENHOR JOSE BORGES DE CARVALHO  Estadual
#
#      VL_APROVACAO_2019_SI_4 VL_INDICADOR_REND_2019 VL_NOTA_MATEMATICA_2019  \
# 4654                   78.2               0.804407                  281.98
# 4655                   79.5               0.799401                  271.79
# ...

# %%
ideb_em_sel.to_csv("pb_sheets/ideb_ensino_medio_pb_2019.csv", index=False)

# %%
cols_exist = [c for c in cols_nec_2019 if c in ideb_final_pb.columns]
ideb_sel = ideb_final_pb[cols_exist].copy()
ideb_sel.head()
# Out:
#       SG_UF  CO_MUNICIPIO NO_MUNICIPIO   ID_ESCOLA  \
# 14151    PB     2500106.0  Água Branca  25033204.0
# 14152    PB     2500106.0  Água Branca  25033212.0
# 14153    PB     2500106.0  Água Branca  25033263.0
# 14154    PB     2500106.0  Água Branca  25033557.0
# 14155    PB     2500106.0  Água Branca  25033670.0
#
#                             NO_ESCOLA       REDE VL_APROVACAO_2019_SI_4  \
# 14151          ECI EEM JOSE NOMINANDO   Estadual                   79.1
# 14152    EEEF JOAO PEREIRA DOS SANTOS   Estadual                      -
# 14153   EEEF PEDRO HERCULANO DA SILVA   Estadual                      -
# 14154   EMEIF DELFINO JOSE DOS SANTOS  Municipal                   96.3
# 14155  EMEF ANTONIO VIRGOLINO BATISTA  Municipal                   96.4
#
#       VL_INDICADOR_REND_2019 VL_NOTA_MATEMATICA_2019 VL_NOTA_PORTUGUES_2019  \
# 14151               0.778935                  245.26                 248.49
# ...

# %%
ideb_sel.to_csv("pb_sheets/ideb_anos_finais_pb_2019.csv", index=False)

# %%
cols_exist = [c for c in cols_nec_2019 if c in ideb_pb.columns]
ideb_sel = ideb_pb[cols_exist].copy()
ideb_sel.head()
# Out:
# 0     SG_UF CO_MUNICIPIO NO_MUNICIPIO ID_ESCOLA  \
# 18619    PB      2500106  Água Branca  25033158
# 18620    PB      2500106  Água Branca  25033557
# 18621    PB      2500106  Água Branca  25033670
# 18622    PB      2500205       Aguiar  25023489
# 18623    PB      2500205       Aguiar  25023535
#
# 0                             NO_ESCOLA       REDE VL_APROVACAO_2019_SI_4  \
# 18619                    EMEIF MAE IAIA  Municipal                   98.3
# 18620     EMEIF DELFINO JOSE DOS SANTOS  Municipal                   97.2
# 18621    EMEF ANTONIO VIRGOLINO BATISTA  Municipal                      -
# 18622     ECI EEM AGENOR MENDES PEDROSA   Estadual                      -
# 18623  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal                      -
#
# 0     VL_INDICADOR_REND_2019 VL_NOTA_MATEMATICA_2019 VL_NOTA_PORTUGUES_2019  \
# 18619               0.982041                  227.71                 215.59
# ...

# %%
ideb_sel.to_csv("pb_sheets/ideb_anos_iniciais_pb_2019.csv", index=False)

# %% [markdown]
# Ideb 2021

# %%
cols_nec_2021 = ['SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO', 'ID_ESCOLA', 'NO_ESCOLA', 'REDE', 'VL_APROVACAO_2021_SI_4', 'VL_INDICADOR_REND_2021', 'VL_NOTA_MATEMATICA_2021', 'VL_NOTA_PORTUGUES_2021', 'VL_NOTA_MEDIA_2021', 'VL_OBSERVADO_2023',
 'VL_PROJECAO_2021']

# %%
cols_exist = [c for c in cols_nec_2021 if c in ideb_em_pb.columns]
ideb_em_sel = ideb_em_pb[cols_exist].copy()
ideb_em_sel.head()
# Out:
#      SG_UF  CO_MUNICIPIO   NO_MUNICIPIO   ID_ESCOLA  \
# 4654    PB     2500106.0    Água Branca  25033204.0
# 4655    PB     2500205.0         Aguiar  25023489.0
# 4656    PB     2500304.0  Alagoa Grande  25062638.0
# 4657    PB     2500304.0  Alagoa Grande  25062816.0
# 4658    PB     2500403.0    Alagoa Nova  25063340.0
#
#                                        NO_ESCOLA      REDE  \
# 4654                      ECI EEM JOSE NOMINANDO  Estadual
# 4655               ECI EEM AGENOR MENDES PEDROSA  Estadual
# 4656                 EEEFM PADRE HILDON BANDEIRA  Estadual
# 4657  ECIT OSWALDO TRIGUEIRO DE ALBUQUERQUE MELO  Estadual
# 4658      ECIT MONSENHOR JOSE BORGES DE CARVALHO  Estadual
#
#      VL_APROVACAO_2021_SI_4 VL_INDICADOR_REND_2021 VL_NOTA_MATEMATICA_2021  \
# 4654                    100                      1                  271.86
# 4655                   98.7               0.989449                      ND
# ...

# %%
ideb_em_sel.to_csv("pb_sheets/ideb_ensino_medio_pb_2021.csv", index=False)

# %%
cols_exist = [c for c in cols_nec_2021 if c in ideb_pb.columns]
ideb_sel = ideb_pb[cols_exist].copy()
ideb_sel.head()
# Out:
# 0     SG_UF CO_MUNICIPIO NO_MUNICIPIO ID_ESCOLA  \
# 18619    PB      2500106  Água Branca  25033158
# 18620    PB      2500106  Água Branca  25033557
# 18621    PB      2500106  Água Branca  25033670
# 18622    PB      2500205       Aguiar  25023489
# 18623    PB      2500205       Aguiar  25023535
#
# 0                             NO_ESCOLA       REDE VL_APROVACAO_2021_SI_4  \
# 18619                    EMEIF MAE IAIA  Municipal                   99.8
# 18620     EMEIF DELFINO JOSE DOS SANTOS  Municipal                    100
# 18621    EMEF ANTONIO VIRGOLINO BATISTA  Municipal                      -
# 18622     ECI EEM AGENOR MENDES PEDROSA   Estadual                      -
# 18623  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal                      -
#
# 0     VL_INDICADOR_REND_2021 VL_NOTA_MATEMATICA_2021 VL_NOTA_PORTUGUES_2021  \
# 18619                0.99778                  234.67                  214.8
# ...

# %%
ideb_sel.to_csv("pb_sheets/ideb_anos_iniciais_pb_2021.csv", index=False)

# %%
cols_exist = [c for c in cols_nec_2021 if c in ideb_final_pb.columns]
ideb_sel = ideb_final_pb[cols_exist].copy()
ideb_sel.head()
# Out:
#       SG_UF  CO_MUNICIPIO NO_MUNICIPIO   ID_ESCOLA  \
# 14151    PB     2500106.0  Água Branca  25033204.0
# 14152    PB     2500106.0  Água Branca  25033212.0
# 14153    PB     2500106.0  Água Branca  25033263.0
# 14154    PB     2500106.0  Água Branca  25033557.0
# 14155    PB     2500106.0  Água Branca  25033670.0
#
#                             NO_ESCOLA       REDE VL_APROVACAO_2021_SI_4  \
# 14151          ECI EEM JOSE NOMINANDO   Estadual                    100
# 14152    EEEF JOAO PEREIRA DOS SANTOS   Estadual                      -
# 14153   EEEF PEDRO HERCULANO DA SILVA   Estadual                      -
# 14154   EMEIF DELFINO JOSE DOS SANTOS  Municipal                    100
# 14155  EMEF ANTONIO VIRGOLINO BATISTA  Municipal                   99.3
#
#       VL_INDICADOR_REND_2021 VL_NOTA_MATEMATICA_2021 VL_NOTA_PORTUGUES_2021  \
# 14151                      1                  222.28                 217.23
# ...

# %%
ideb_sel.to_csv("pb_sheets/ideb_anos_finais_pb_2021.csv", index=False)

# %% [markdown]
# Calculo resultado nota - meta

# %% [markdown]
# 2017

# %%
# Converter strings para números (substitui vírgula por ponto e ignora erros)
ideb_pb["VL_PROJECAO_2017"] = (
    ideb_pb["VL_PROJECAO_2017"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_pb["VL_PROJECAO_2017"] = pd.to_numeric(ideb_pb["VL_PROJECAO_2017"], errors="coerce")

ideb_pb["VL_OBSERVADO_2017"] = (
    ideb_pb["VL_OBSERVADO_2017"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_pb["VL_OBSERVADO_2017"] = pd.to_numeric(ideb_pb["VL_OBSERVADO_2017"], errors="coerce")

# %%
ideb_pb["RESULTADO_2017"] = ideb_pb["VL_OBSERVADO_2017"] - ideb_pb["VL_PROJECAO_2017"]

# %%
ideb_pb[["NO_MUNICIPIO", "NO_ESCOLA", "REDE", "VL_PROJECAO_2017", "VL_OBSERVADO_2017", "RESULTADO_2017"]].head()
# Out:
# 0     NO_MUNICIPIO                         NO_ESCOLA       REDE  \
# 18619  Água Branca                    EMEIF MAE IAIA  Municipal
# 18620  Água Branca     EMEIF DELFINO JOSE DOS SANTOS  Municipal
# 18621  Água Branca    EMEF ANTONIO VIRGOLINO BATISTA  Municipal
# 18622       Aguiar     ECI EEM AGENOR MENDES PEDROSA   Estadual
# 18623       Aguiar  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal
#
# 0      VL_PROJECAO_2017  VL_OBSERVADO_2017  RESULTADO_2017
# 18619               5.5                6.1             0.6
# 18620               4.6                6.5             1.9
# 18621               5.5                NaN             NaN
# 18622               4.0                NaN             NaN
# 18623               4.2                4.0            -0.2

# %%
cols_nec_2017 = ['SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO', 'ID_ESCOLA', 'NO_ESCOLA', 'REDE', 'VL_APROVACAO_2017_SI_4', 'VL_INDICADOR_REND_2017', 'VL_NOTA_MATEMATICA_2017', 'VL_NOTA_PORTUGUES_2017', 'VL_NOTA_MEDIA_2017', 'VL_OBSERVADO_2017', 'VL_PROJECAO_2017', 'RESULTADO_2017']

# %%
cols_exist = [c for c in cols_nec_2017 if c in ideb_pb.columns]
ideb_sel = ideb_pb[cols_exist].copy()
ideb_sel.head()
# Out:
# 0     SG_UF CO_MUNICIPIO NO_MUNICIPIO ID_ESCOLA  \
# 18619    PB      2500106  Água Branca  25033158
# 18620    PB      2500106  Água Branca  25033557
# 18621    PB      2500106  Água Branca  25033670
# 18622    PB      2500205       Aguiar  25023489
# 18623    PB      2500205       Aguiar  25023535
#
# 0                             NO_ESCOLA       REDE VL_APROVACAO_2017_SI_4  \
# 18619                    EMEIF MAE IAIA  Municipal                   95.2
# 18620     EMEIF DELFINO JOSE DOS SANTOS  Municipal                   95.7
# 18621    EMEF ANTONIO VIRGOLINO BATISTA  Municipal                      -
# 18622     ECI EEM AGENOR MENDES PEDROSA   Estadual                    100
# 18623  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal                   73.1
#
# 0     VL_INDICADOR_REND_2017 VL_NOTA_MATEMATICA_2017 VL_NOTA_PORTUGUES_2017  \
# 18619               0.955293                  236.57                 214.85
# ...

# %%
ideb_sel.to_csv("resultados/ideb_anos_iniciais_pb_2017.csv", index=False)

# %% [markdown]
# nao tem metas de 2017 pra o ideb_em

# %%
# Converter strings para números (substitui vírgula por ponto e ignora erros)
ideb_final_pb["VL_PROJECAO_2017"] = (
    ideb_final_pb["VL_PROJECAO_2017"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_final_pb["VL_PROJECAO_2017"] = pd.to_numeric(ideb_final_pb["VL_PROJECAO_2017"], errors="coerce")

ideb_final_pb["VL_OBSERVADO_2017"] = (
    ideb_final_pb["VL_OBSERVADO_2017"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_final_pb["VL_OBSERVADO_2017"] = pd.to_numeric(ideb_final_pb["VL_OBSERVADO_2017"], errors="coerce")

# %%
# Calculo resultado
ideb_final_pb["RESULTADO_2017"] = ideb_final_pb["VL_OBSERVADO_2017"] - ideb_final_pb["VL_PROJECAO_2017"]

# %%
ideb_final_pb[["NO_MUNICIPIO", "NO_ESCOLA", "REDE", "VL_PROJECAO_2021", "VL_OBSERVADO_2017", "RESULTADO_2017"]].head()
# Out:
#       NO_MUNICIPIO                       NO_ESCOLA       REDE  \
# 14151  Água Branca          ECI EEM JOSE NOMINANDO   Estadual
# 14152  Água Branca    EEEF JOAO PEREIRA DOS SANTOS   Estadual
# 14153  Água Branca   EEEF PEDRO HERCULANO DA SILVA   Estadual
# 14154  Água Branca   EMEIF DELFINO JOSE DOS SANTOS  Municipal
# 14155  Água Branca  EMEF ANTONIO VIRGOLINO BATISTA  Municipal
#
#       VL_PROJECAO_2021  VL_OBSERVADO_2017  RESULTADO_2017
# 14151              4.7                4.0            -0.1
# 14152              3.8                NaN             NaN
# 14153              4.6                NaN             NaN
# 14154              3.8                5.5             2.2
# 14155              4.7                5.0             0.8

# %%
cols_nec_2017 = ['SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO', 'ID_ESCOLA', 'NO_ESCOLA', 'REDE', 'VL_APROVACAO_2017_SI_4', 'VL_INDICADOR_REND_2017', 'VL_NOTA_MATEMATICA_2017', 'VL_NOTA_PORTUGUES_2017', 'VL_NOTA_MEDIA_2017', 'VL_OBSERVADO_2017', 'VL_PROJECAO_2017', 'RESULTADO_2017']

# %%
cols_exist = [c for c in cols_nec_2017 if c in ideb_final_pb.columns]
ideb_sel = ideb_final_pb[cols_exist].copy()
ideb_sel.head()
# Out:
#       SG_UF  CO_MUNICIPIO NO_MUNICIPIO   ID_ESCOLA  \
# 14151    PB     2500106.0  Água Branca  25033204.0
# 14152    PB     2500106.0  Água Branca  25033212.0
# 14153    PB     2500106.0  Água Branca  25033263.0
# 14154    PB     2500106.0  Água Branca  25033557.0
# 14155    PB     2500106.0  Água Branca  25033670.0
#
#                             NO_ESCOLA       REDE VL_APROVACAO_2017_SI_4  \
# 14151          ECI EEM JOSE NOMINANDO   Estadual                   80.9
# 14152    EEEF JOAO PEREIRA DOS SANTOS   Estadual                      -
# 14153   EEEF PEDRO HERCULANO DA SILVA   Estadual                      -
# 14154   EMEIF DELFINO JOSE DOS SANTOS  Municipal                   96.6
# 14155  EMEF ANTONIO VIRGOLINO BATISTA  Municipal                     89
#
#       VL_INDICADOR_REND_2017 VL_NOTA_MATEMATICA_2017 VL_NOTA_PORTUGUES_2017  \
# 14151                0.79805                  249.23                 249.06
# ...

# %%
ideb_sel.to_csv("resultados/ideb_anos_finais_pb_2017.csv", index=False)

# %% [markdown]
# 2019

# %%
# Converter strings para números (substitui vírgula por ponto e ignora erros)
ideb_pb["VL_PROJECAO_2019"] = (
    ideb_pb["VL_PROJECAO_2019"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_pb["VL_PROJECAO_2019"] = pd.to_numeric(ideb_pb["VL_PROJECAO_2019"], errors="coerce")

ideb_pb["VL_OBSERVADO_2019"] = (
    ideb_pb["VL_OBSERVADO_2019"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_pb["VL_OBSERVADO_2019"] = pd.to_numeric(ideb_pb["VL_OBSERVADO_2019"], errors="coerce")

# %%
ideb_pb["RESULTADO_2019"] = ideb_pb["VL_OBSERVADO_2019"] - ideb_pb["VL_PROJECAO_2019"]

# %%
ideb_pb[["NO_MUNICIPIO", "NO_ESCOLA", "REDE", "VL_PROJECAO_2021", "VL_OBSERVADO_2019", "RESULTADO_2019"]].head()
# Out:
# 0     NO_MUNICIPIO                         NO_ESCOLA       REDE  \
# 18619  Água Branca                    EMEIF MAE IAIA  Municipal
# 18620  Água Branca     EMEIF DELFINO JOSE DOS SANTOS  Municipal
# 18621  Água Branca    EMEF ANTONIO VIRGOLINO BATISTA  Municipal
# 18622       Aguiar     ECI EEM AGENOR MENDES PEDROSA   Estadual
# 18623       Aguiar  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal
#
# 0     VL_PROJECAO_2021  VL_OBSERVADO_2019  RESULTADO_2019
# 18619              6.1                6.1             0.3
# 18620              5.2                5.3             0.4
# 18621                6                NaN             NaN
# 18622              4.6                NaN             NaN
# 18623              4.9                NaN             NaN

# %%
cols_nec_2019 = ['SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO', 'ID_ESCOLA', 'NO_ESCOLA', 'REDE', 'VL_APROVACAO_2019_SI_4', 'VL_INDICADOR_REND_2019', 'VL_NOTA_MATEMATICA_2019', 'VL_NOTA_PORTUGUES_2019', 'VL_NOTA_MEDIA_2019', 'VL_OBSERVADO_2019','VL_PROJECAO_2019', 'RESULTADO_2019']

# %%
cols_exist = [c for c in cols_nec_2019 if c in ideb_pb.columns]
ideb_sel = ideb_pb[cols_exist].copy()
ideb_sel.head()
# Out:
# 0     SG_UF CO_MUNICIPIO NO_MUNICIPIO ID_ESCOLA  \
# 18619    PB      2500106  Água Branca  25033158
# 18620    PB      2500106  Água Branca  25033557
# 18621    PB      2500106  Água Branca  25033670
# 18622    PB      2500205       Aguiar  25023489
# 18623    PB      2500205       Aguiar  25023535
#
# 0                             NO_ESCOLA       REDE VL_APROVACAO_2019_SI_4  \
# 18619                    EMEIF MAE IAIA  Municipal                   98.3
# 18620     EMEIF DELFINO JOSE DOS SANTOS  Municipal                   97.2
# 18621    EMEF ANTONIO VIRGOLINO BATISTA  Municipal                      -
# 18622     ECI EEM AGENOR MENDES PEDROSA   Estadual                      -
# 18623  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal                      -
#
# 0     VL_INDICADOR_REND_2019 VL_NOTA_MATEMATICA_2019 VL_NOTA_PORTUGUES_2019  \
# 18619               0.982041                  227.71                 215.59
# ...

# %%
ideb_sel.to_csv("resultados/ideb_anos_iniciais_pb_2019.csv", index=False)

# %%
# Converter strings para números (substitui vírgula por ponto e ignora erros)
ideb_em_pb["VL_PROJECAO_2019"] = (
    ideb_em_pb["VL_PROJECAO_2019"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_em_pb["VL_PROJECAO_2019"] = pd.to_numeric(ideb_em_pb["VL_PROJECAO_2019"], errors="coerce")

ideb_em_pb["VL_OBSERVADO_2019"] = (
    ideb_em_pb["VL_OBSERVADO_2019"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_em_pb["VL_OBSERVADO_2019"] = pd.to_numeric(ideb_em_pb["VL_OBSERVADO_2019"], errors="coerce")

# %%
# Calculo resultado
ideb_em_pb["RESULTADO_2019"] = ideb_em_pb["VL_OBSERVADO_2019"] - ideb_em_pb["VL_PROJECAO_2019"]

# %%
ideb_em_pb[["NO_MUNICIPIO", "NO_ESCOLA", "REDE", "VL_PROJECAO_2019", "VL_OBSERVADO_2019", "RESULTADO_2019"]].head()
# Out:
#        NO_MUNICIPIO                                   NO_ESCOLA      REDE  \
# 4654    Água Branca                      ECI EEM JOSE NOMINANDO  Estadual
# 4655         Aguiar               ECI EEM AGENOR MENDES PEDROSA  Estadual
# 4656  Alagoa Grande                 EEEFM PADRE HILDON BANDEIRA  Estadual
# 4657  Alagoa Grande  ECIT OSWALDO TRIGUEIRO DE ALBUQUERQUE MELO  Estadual
# 4658    Alagoa Nova      ECIT MONSENHOR JOSE BORGES DE CARVALHO  Estadual
#
#       VL_PROJECAO_2019  VL_OBSERVADO_2019  RESULTADO_2019
# 4654               4.0                3.8            -0.2
# 4655               3.3                3.6             0.3
# 4656               NaN                NaN             NaN
# 4657               NaN                NaN             NaN
# 4658               3.0                3.5             0.5

# %%
cols_exist = [c for c in cols_nec_2019 if c in ideb_em_pb.columns]
ideb_sel = ideb_em_pb[cols_exist].copy()
ideb_sel.head()
# Out:
#      SG_UF  CO_MUNICIPIO   NO_MUNICIPIO   ID_ESCOLA  \
# 4654    PB     2500106.0    Água Branca  25033204.0
# 4655    PB     2500205.0         Aguiar  25023489.0
# 4656    PB     2500304.0  Alagoa Grande  25062638.0
# 4657    PB     2500304.0  Alagoa Grande  25062816.0
# 4658    PB     2500403.0    Alagoa Nova  25063340.0
#
#                                        NO_ESCOLA      REDE  \
# 4654                      ECI EEM JOSE NOMINANDO  Estadual
# 4655               ECI EEM AGENOR MENDES PEDROSA  Estadual
# 4656                 EEEFM PADRE HILDON BANDEIRA  Estadual
# 4657  ECIT OSWALDO TRIGUEIRO DE ALBUQUERQUE MELO  Estadual
# 4658      ECIT MONSENHOR JOSE BORGES DE CARVALHO  Estadual
#
#      VL_APROVACAO_2019_SI_4 VL_INDICADOR_REND_2019 VL_NOTA_MATEMATICA_2019  \
# 4654                   78.2               0.804407                  281.98
# 4655                   79.5               0.799401                  271.79
# ...

# %%
ideb_sel.to_csv("resultados/ideb_ensino_medio_pb_2019.csv", index=False)

# %%
# Converter strings para números (substitui vírgula por ponto e ignora erros)
ideb_final_pb["VL_PROJECAO_2019"] = (
    ideb_final_pb["VL_PROJECAO_2019"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_final_pb["VL_PROJECAO_2019"] = pd.to_numeric(ideb_final_pb["VL_PROJECAO_2019"], errors="coerce")

ideb_final_pb["VL_OBSERVADO_2019"] = (
    ideb_final_pb["VL_OBSERVADO_2019"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_final_pb["VL_OBSERVADO_2019"] = pd.to_numeric(ideb_final_pb["VL_OBSERVADO_2019"], errors="coerce")

# %%
# Calculo resultado
ideb_final_pb["RESULTADO_2019"] = ideb_final_pb["VL_OBSERVADO_2019"] - ideb_final_pb["VL_PROJECAO_2019"]

# %%
ideb_final_pb[["NO_MUNICIPIO", "NO_ESCOLA", "REDE", "VL_PROJECAO_2019", "VL_OBSERVADO_2019", "RESULTADO_2019"]].head()
# Out:
#       NO_MUNICIPIO                       NO_ESCOLA       REDE  \
# 14151  Água Branca          ECI EEM JOSE NOMINANDO   Estadual
# 14152  Água Branca    EEEF JOAO PEREIRA DOS SANTOS   Estadual
# 14153  Água Branca   EEEF PEDRO HERCULANO DA SILVA   Estadual
# 14154  Água Branca   EMEIF DELFINO JOSE DOS SANTOS  Municipal
# 14155  Água Branca  EMEF ANTONIO VIRGOLINO BATISTA  Municipal
#
#        VL_PROJECAO_2019  VL_OBSERVADO_2019  RESULTADO_2019
# 14151               4.4                3.8            -0.6
# 14152               3.5                NaN             NaN
# 14153               4.3                NaN             NaN
# 14154               3.5                5.9             2.4
# 14155               4.4                5.8             1.4

# %%
cols_exist = [c for c in cols_nec_2019 if c in ideb_final_pb.columns]
ideb_sel = ideb_final_pb[cols_exist].copy()
ideb_sel.head()
# Out:
#       SG_UF  CO_MUNICIPIO NO_MUNICIPIO   ID_ESCOLA  \
# 14151    PB     2500106.0  Água Branca  25033204.0
# 14152    PB     2500106.0  Água Branca  25033212.0
# 14153    PB     2500106.0  Água Branca  25033263.0
# 14154    PB     2500106.0  Água Branca  25033557.0
# 14155    PB     2500106.0  Água Branca  25033670.0
#
#                             NO_ESCOLA       REDE VL_APROVACAO_2019_SI_4  \
# 14151          ECI EEM JOSE NOMINANDO   Estadual                   79.1
# 14152    EEEF JOAO PEREIRA DOS SANTOS   Estadual                      -
# 14153   EEEF PEDRO HERCULANO DA SILVA   Estadual                      -
# 14154   EMEIF DELFINO JOSE DOS SANTOS  Municipal                   96.3
# 14155  EMEF ANTONIO VIRGOLINO BATISTA  Municipal                   96.4
#
#       VL_INDICADOR_REND_2019 VL_NOTA_MATEMATICA_2019 VL_NOTA_PORTUGUES_2019  \
# 14151               0.778935                  245.26                 248.49
# ...

# %%
ideb_sel.to_csv("resultados/ideb_anos_finais_pb_2019.csv", index=False)

# %% [markdown]
# 2021

# %%
# Converter strings para números (substitui vírgula por ponto e ignora erros)
ideb_pb["VL_PROJECAO_2021"] = (
    ideb_pb["VL_PROJECAO_2021"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_pb["VL_PROJECAO_2021"] = pd.to_numeric(ideb_pb["VL_PROJECAO_2021"], errors="coerce")

ideb_pb["VL_OBSERVADO_2021"] = (
    ideb_pb["VL_OBSERVADO_2021"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_pb["VL_OBSERVADO_2021"] = pd.to_numeric(ideb_pb["VL_OBSERVADO_2021"], errors="coerce")

# %%
# Calculo resultado
ideb_pb["RESULTADO_2021"] = ideb_pb["VL_OBSERVADO_2021"] - ideb_pb["VL_PROJECAO_2021"]

# %%
ideb_pb[["NO_MUNICIPIO", "NO_ESCOLA", "REDE", "VL_PROJECAO_2021", "VL_OBSERVADO_2021", "RESULTADO_2021"]].head()
# Out:
# 0     NO_MUNICIPIO                         NO_ESCOLA       REDE  \
# 18619  Água Branca                    EMEIF MAE IAIA  Municipal
# 18620  Água Branca     EMEIF DELFINO JOSE DOS SANTOS  Municipal
# 18621  Água Branca    EMEF ANTONIO VIRGOLINO BATISTA  Municipal
# 18622       Aguiar     ECI EEM AGENOR MENDES PEDROSA   Estadual
# 18623       Aguiar  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal
#
# 0      VL_PROJECAO_2021  VL_OBSERVADO_2021  RESULTADO_2021
# 18619               6.1                6.3             0.2
# 18620               5.2                6.2             1.0
# 18621               6.0                NaN             NaN
# 18622               4.6                NaN             NaN
# 18623               4.9                NaN             NaN

# %%
cols_nec_2021 = ['SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO', 'ID_ESCOLA', 'NO_ESCOLA', 'REDE', 'VL_APROVACAO_2021_SI_4', 'VL_INDICADOR_REND_2021', 'VL_NOTA_MATEMATICA_2021', 'VL_NOTA_PORTUGUES_2021', 'VL_NOTA_MEDIA_2021', 'VL_OBSERVADO_2023', 'VL_PROJECAO_2021', 'RESULTADO_2021']

# %%
cols_exist = [c for c in cols_nec_2021 if c in ideb_pb.columns]
ideb_sel = ideb_pb[cols_exist].copy()
ideb_sel.head()
# Out:
# 0     SG_UF CO_MUNICIPIO NO_MUNICIPIO ID_ESCOLA  \
# 18619    PB      2500106  Água Branca  25033158
# 18620    PB      2500106  Água Branca  25033557
# 18621    PB      2500106  Água Branca  25033670
# 18622    PB      2500205       Aguiar  25023489
# 18623    PB      2500205       Aguiar  25023535
#
# 0                             NO_ESCOLA       REDE VL_APROVACAO_2021_SI_4  \
# 18619                    EMEIF MAE IAIA  Municipal                   99.8
# 18620     EMEIF DELFINO JOSE DOS SANTOS  Municipal                    100
# 18621    EMEF ANTONIO VIRGOLINO BATISTA  Municipal                      -
# 18622     ECI EEM AGENOR MENDES PEDROSA   Estadual                      -
# 18623  EMEIEFCNNM LIDIA CABRAL DE SOUSA  Municipal                      -
#
# 0     VL_INDICADOR_REND_2021 VL_NOTA_MATEMATICA_2021 VL_NOTA_PORTUGUES_2021  \
# 18619                0.99778                  234.67                  214.8
# ...

# %%
ideb_sel.to_csv("resultados/ideb_anos_iniciais_pb_2021.csv", index=False)

# %%
# Converter strings para números (substitui vírgula por ponto e ignora erros)
ideb_em_pb["VL_PROJECAO_2021"] = (
    ideb_em_pb["VL_PROJECAO_2021"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_em_pb["VL_PROJECAO_2021"] = pd.to_numeric(ideb_em_pb["VL_PROJECAO_2021"], errors="coerce")

ideb_em_pb["VL_OBSERVADO_2021"] = (
    ideb_em_pb["VL_OBSERVADO_2021"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_em_pb["VL_OBSERVADO_2021"] = pd.to_numeric(ideb_em_pb["VL_OBSERVADO_2021"], errors="coerce")

# %%
# Calculo resultado
ideb_em_pb["RESULTADO_2021"] = ideb_em_pb["VL_OBSERVADO_2021"] - ideb_em_pb["VL_PROJECAO_2021"]

# %%
ideb_em_pb[["NO_MUNICIPIO", "NO_ESCOLA", "REDE", "VL_PROJECAO_2021", "VL_OBSERVADO_2021", "RESULTADO_2021"]].head()
# Out:
#        NO_MUNICIPIO                                   NO_ESCOLA      REDE  \
# 4654    Água Branca                      ECI EEM JOSE NOMINANDO  Estadual
# 4655         Aguiar               ECI EEM AGENOR MENDES PEDROSA  Estadual
# 4656  Alagoa Grande                 EEEFM PADRE HILDON BANDEIRA  Estadual
# 4657  Alagoa Grande  ECIT OSWALDO TRIGUEIRO DE ALBUQUERQUE MELO  Estadual
# 4658    Alagoa Nova      ECIT MONSENHOR JOSE BORGES DE CARVALHO  Estadual
#
#       VL_PROJECAO_2021  VL_OBSERVADO_2021  RESULTADO_2021
# 4654               4.2                4.6             0.4
# 4655               3.5                NaN             NaN
# 4656               NaN                NaN             NaN
# 4657               NaN                NaN             NaN
# 4658               3.2                NaN             NaN

# %%
cols_nec_2021 = ['SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO', 'ID_ESCOLA', 'NO_ESCOLA', 'REDE', 'VL_APROVACAO_2021_SI_4', 'VL_INDICADOR_REND_2021', 'VL_NOTA_MATEMATICA_2021', 'VL_NOTA_PORTUGUES_2021', 'VL_NOTA_MEDIA_2021', 'VL_OBSERVADO_2021', "RESULTADO_2021", 'VL_PROJECAO_2021', 'RESULTADO_2021']

# %%
cols_exist = [c for c in cols_nec_2021 if c in ideb_em_pb.columns]
ideb_sel = ideb_em_pb[cols_exist].copy()

# %%
ideb_sel.to_csv("resultados/ideb_ensino_medio_pb_2021.csv", index=False)

# %%
# Converter strings para números (substitui vírgula por ponto e ignora erros)
ideb_final_pb["VL_PROJECAO_2021"] = (
    ideb_final_pb["VL_PROJECAO_2021"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_final_pb["VL_PROJECAO_2021"] = pd.to_numeric(ideb_final_pb["VL_PROJECAO_2021"], errors="coerce")

ideb_final_pb["VL_OBSERVADO_2021"] = (
    ideb_final_pb["VL_OBSERVADO_2021"]
    .astype(str)
    .str.replace(",", ".", regex=False)
)
ideb_final_pb["VL_OBSERVADO_2021"] = pd.to_numeric(ideb_final_pb["VL_OBSERVADO_2021"], errors="coerce")

# %%
# Calculo resultado
ideb_final_pb["RESULTADO_2021"] = ideb_final_pb["VL_OBSERVADO_2021"] - ideb_final_pb["VL_PROJECAO_2021"]

# %%
ideb_final_pb[["NO_MUNICIPIO", "NO_ESCOLA", "REDE", "VL_PROJECAO_2021", "VL_OBSERVADO_2021", "RESULTADO_2021"]].head()
# Out:
#       NO_MUNICIPIO                       NO_ESCOLA       REDE  \
# 14151  Água Branca          ECI EEM JOSE NOMINANDO   Estadual
# 14152  Água Branca    EEEF JOAO PEREIRA DOS SANTOS   Estadual
# 14153  Água Branca   EEEF PEDRO HERCULANO DA SILVA   Estadual
# 14154  Água Branca   EMEIF DELFINO JOSE DOS SANTOS  Municipal
# 14155  Água Branca  EMEF ANTONIO VIRGOLINO BATISTA  Municipal
#
#        VL_PROJECAO_2021  VL_OBSERVADO_2021  RESULTADO_2021
# 14151               4.7                4.0            -0.7
# 14152               3.8                NaN             NaN
# 14153               4.6                NaN             NaN
# 14154               3.8                5.6             1.8
# 14155               4.7                6.0             1.3

# %%
cols_exist = [c for c in cols_nec_2021 if c in ideb_final_pb.columns]
ideb_sel = ideb_final_pb[cols_exist].copy()

# %%
ideb_sel.to_csv("resultados/ideb_anos_finais_pb_2021.csv", index=False)

# %% [markdown]
# separado todas as colunas todos os anos

# %%
cols_nec = ['SG_UF', 'CO_MUNICIPIO', 'NO_MUNICIPIO', 'ID_ESCOLA', 'NO_ESCOLA', 'REDE', 'VL_APROVACAO_2017_SI_4', 'VL_APROVACAO_2019_SI_4', 'VL_APROVACAO_2021_SI_4', 'VL_INDICADOR_REND_2017', 'VL_INDICADOR_REND_2019', 'VL_INDICADOR_REND_2021', 'VL_NOTA_MATEMATICA_2017', 'VL_NOTA_MATEMATICA_2019', 'VL_NOTA_MATEMATICA_2021', 'VL_NOTA_PORTUGUES_2017', 'VL_NOTA_PORTUGUES_2019', 'VL_NOTA_PORTUGUES_2021', 'VL_NOTA_MEDIA_2017', 'VL_NOTA_MEDIA_2019', 'VL_NOTA_MEDIA_2021', 'VL_OBSERVADO_2017', 'VL_OBSERVADO_2019', 'VL_OBSERVADO_2021', 'VL_PROJECAO_2017', 'VL_PROJECAO_2019', 'VL_PROJECAO_2021', 'RESULTADO_2017', 'RESULTADO_2019', 'RESULTADO_2021']

# %%
cols_exist = [c for c in cols_nec if c in ideb_final_pb.columns]
ideb_sel = ideb_final_pb[cols_exist].copy()

# %%
from pathlib import Path

out_path = Path("resultados_compactos/IDEB_ANOS_FINAIS_PB.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)

if not out_path.exists():
    ideb_sel.to_csv(out_path, index=False)
    print(f"Created: {out_path}")
else:
    print(f"File already exists: {out_path} (no action taken)")
# Out:
# Created: resultados_compactos\IDEB_ANOS_FINAIS_PB.csv

# %%
cols_exist = [c for c in cols_nec if c in ideb_pb.columns]
ideb_sel = ideb_pb[cols_exist].copy()

# %%
from pathlib import Path

out_path = Path("resultados_compactos/IDEB_ANOS_INICIAIS_PB.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)

if not out_path.exists():
    ideb_sel.to_csv(out_path, index=False)
    print(f"Created: {out_path}")
else:
    print(f"File already exists: {out_path} (no action taken)")
# Out:
# Created: resultados_compactos\IDEB_ANOS_INICIAIS_PB.csv

# %%
cols_exist = [c for c in cols_nec if c in ideb_em_pb.columns]
ideb_sel = ideb_em_pb[cols_exist].copy()

# %%
from pathlib import Path

out_path = Path("resultados_compactos/IDEB_ENSINO_MEDIO_PB.csv")
out_path.parent.mkdir(parents=True, exist_ok=True)

if not out_path.exists():
    ideb_sel.to_csv(out_path, index=False)
    print(f"Created: {out_path}")
else:
    print(f"File already exists: {out_path} (no action taken)")
# Out:
# Created: resultados_compactos\IDEB_ENSINO_MEDIO_PB.csv

# %%
from pathlib import Path

path = Path("resultados_compactos/IDEB_ENSINO_MEDIO_PB.csv")
if not path.exists():
    raise FileNotFoundError(f"{path} not found. Check spelling or run the cell that creates it.")

# CSV was saved with standard header, so read normally
df = pd.read_csv(path)

df.head()
# Out:
#   SG_UF  CO_MUNICIPIO   NO_MUNICIPIO   ID_ESCOLA  \
# 0    PB     2500106.0    Água Branca  25033204.0
# 1    PB     2500205.0         Aguiar  25023489.0
# 2    PB     2500304.0  Alagoa Grande  25062638.0
# 3    PB     2500304.0  Alagoa Grande  25062816.0
# 4    PB     2500403.0    Alagoa Nova  25063340.0
#
#                                     NO_ESCOLA      REDE  \
# 0                      ECI EEM JOSE NOMINANDO  Estadual
# 1               ECI EEM AGENOR MENDES PEDROSA  Estadual
# 2                 EEEFM PADRE HILDON BANDEIRA  Estadual
# 3  ECIT OSWALDO TRIGUEIRO DE ALBUQUERQUE MELO  Estadual
# 4      ECIT MONSENHOR JOSE BORGES DE CARVALHO  Estadual
#
#   VL_APROVACAO_2017_SI_4 VL_APROVACAO_2019_SI_4 VL_APROVACAO_2021_SI_4  \
# 0                   85.5                   78.2                    100
# 1                   87.2                   79.5                   98.7
# 2                   64.8                   55.7                   99.1
# ...
